# %%
# Importa bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Acessa os dados subidos (Dados_imersao e Avaliacoes)
dados = pd.read_csv('/content/Dados_imersao - Dados.csv')
avaliacoes = pd.read_csv('/content/Avaliacoes - Avaliacoes.csv')

# %%
# Exibe os dados de forma simplificada
print(dados.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#   actual_price product_price percent_discount actual_price_real rating  \
# 0      ₹399,00     ₹1.099,00           63,69%           R$23,86      5
# 1      ₹199,00       ₹349,00           42,98%           R$11,90      5
# 2      ₹199,00     ₹1.899,00           89,52%           R$11,90      5
# 3      ₹329,00       ₹699,00           52,93%           R$19,67   4,52
# 4      ₹154,00       ₹399,00           61,40%            R$9,21   4,52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Exibe os dados mais elaboradamente
dados.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#   actual_price product_price percent_discount actual_price_real rating  \
# 0      ₹399,00     ₹1.099,00           63,69%           R$23,86      5
# 1      ₹199,00       ₹349,00           42,98%           R$11,90      5
# 2      ₹199,00     ₹1.899,00           89,52%           R$11,90      5
# 3      ₹329,00       ₹699,00           52,93%           R$19,67   4,52
# 4      ₹154,00       ₹399,00           61,40%            R$9,21   4,52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Exibe as duas primeiras linhas da tabela "dados"
dados.head(2)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#   actual_price product_price percent_discount actual_price_real rating  \
# 0      ₹399,00     ₹1.099,00           63,69%           R$23,86      5
# 1      ₹199,00       ₹349,00           42,98%           R$11,90      5
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...

# %%
# Exibe as regras de formatação de cada coluna
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1465 non-null   object
#  1   product_name       1465 non-null   object
#  2   category           1465 non-null   object
#  3   Subcategory        1465 non-null   object
#  4   actual_price       1465 non-null   object
#  5   product_price      1465 non-null   object
#  6   percent_discount   1465 non-null   object
#  7   actual_price_real  1465 non-null   object
#  8   rating             1465 non-null   object
#  9   rating_count       1465 non-null   int64
#  10  about_product      1465 non-null   object
#  11  product_link       1465 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 137.5+ KB

# %%
dados.describe()
# Out:
#        rating_count
# count  1.465000e+03
# mean   2.166947e+04
# std    9.132905e+04
# min    0.000000e+00
# 25%    9.100000e+02
# 50%    4.003000e+03
# 75%    1.466700e+04
# max    2.051952e+06

# %%
# Supondo que o símbolo da rupia seja '₹', busca o símbolo como string e substitui por nada
dados['actual_price'] = dados['actual_price'].str.replace('₹', '')

# %%
# Substitui ponto por nada
dados['actual_price'] = dados['actual_price'].str.replace('.', '')
# Out:
# <ipython-input-65-f3231eeba866>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['actual_price'] = dados['actual_price'].str.replace('.', '')

# %%
# Subistitui vírgula por ponto
dados['actual_price'] = dados['actual_price'].str.replace(',', '.')

# %%
# Convertendo a coluna para o tipo numérico (opcional)
dados['actual_price'] = pd.to_numeric(dados['actual_price'])

# %%
# Exibindo os primeiros registros após a remoção do símbolo da moeda
dados.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#    actual_price product_price percent_discount actual_price_real rating  \
# 0         399.0     ₹1.099,00           63,69%           R$23,86      5
# 1         199.0       ₹349,00           42,98%           R$11,90      5
# 2         199.0     ₹1.899,00           89,52%           R$11,90      5
# 3         329.0       ₹699,00           52,93%           R$19,67   4,52
# 4         154.0       ₹399,00           61,40%            R$9,21   4,52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Substitui caracteres
dados['product_price'] = dados['product_price'].str.replace('₹','').str.replace('.', '').str.replace(',', '.')
# Out:
# <ipython-input-69-032a40939507>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['product_price'] = dados['product_price'].str.replace('₹','').str.replace('.', '').str.replace(',', '.')

# %%
dados.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#    actual_price product_price percent_discount actual_price_real rating  \
# 0         399.0       1099.00           63,69%           R$23,86      5
# 1         199.0        349.00           42,98%           R$11,90      5
# 2         199.0       1899.00           89,52%           R$11,90      5
# 3         329.0        699.00           52,93%           R$19,67   4,52
# 4         154.0        399.00           61,40%            R$9,21   4,52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Função para transformar os números em string
#dados['product_price'] = dados['product_price'].astype(str)

# %%
# Função lambda para inserir um ponto antes dos dois últimos dígitos do número
#dados['product_price'] = dados['product_price'].apply(lambda x: x[:-2] + '.' + x[-2:])

# %%
dados.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#    actual_price  product_price percent_discount actual_price_real rating  \
# 0         399.0         1099.0           63,69%           R$23,86      5
# 1         199.0          349.0           42,98%           R$11,90      5
# 2         199.0         1899.0           89,52%           R$11,90      5
# 3         329.0          699.0           52,93%           R$19,67   4.52
# 4         154.0          399.0           61,40%            R$9,21   4.52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Converte coluna para tipo numérico
dados['product_price'] = pd.to_numeric(dados['product_price'])

# %%
dados['rating'] = dados['rating'].str.replace(',', '.')

# %%
# Converte coluna para tipo numérico
dados['rating'] = pd.to_numeric(dados['rating'])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1465 non-null   object
#  1   product_name       1465 non-null   object
#  2   category           1465 non-null   object
#  3   Subcategory        1465 non-null   object
#  4   actual_price       1465 non-null   float64
#  5   product_price      1465 non-null   float64
#  6   percent_discount   1465 non-null   object
#  7   actual_price_real  1465 non-null   object
#  8   rating             1465 non-null   object
#  9   rating_count       1465 non-null   int64
#  10  about_product      1465 non-null   object
#  11  product_link       1465 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 137.5+ KB

# %%
dados.describe()
# Out:
#        actual_price  product_price  rating_count
# count   1465.000000    1465.000000  1.465000e+03
# mean    3077.617693    5365.248840  2.166947e+04
# std     6860.277463   10743.796284  9.132905e+04
# min        2.500000      38.000000  0.000000e+00
# 25%      314.000000     800.000000  9.100000e+02
# 50%      799.000000    1645.000000  4.003000e+03
# 75%     1999.000000    4199.000000  1.466700e+04
# max    77990.000000  139900.000000  2.051952e+06

# %%
dados.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category              Subcategory  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 1  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 2  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 3  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
# 4  Computers&Accessories|Accessories&Peripherals|...  Accessories&Peripherals
#
#    actual_price  product_price percent_discount  actual_price_real rating  \
# 0         399.0         1099.0           63,69%              23.86      5
# 1         199.0          349.0           42,98%              11.90      5
# 2         199.0         1899.0           89,52%              11.90      5
# 3         329.0          699.0           52,93%              19.67   4.52
# 4         154.0          399.0           61,40%               9.21   4.52
#
#    rating_count                                      about_product  \
# 0         24269  High Compatibility : Compatible With iPhone 12...
# 1         43994  Compatible with all Type C enabled devices, be...
# 2          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# Remove o símbolo "R$"
dados['actual_price_real'] = dados['actual_price_real'].str.replace('R\$', '')
# Out:
# <ipython-input-80-a196163b8890>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dados['actual_price_real'] = dados['actual_price_real'].str.replace('R\$', '')

# %%
dados['actual_price_real'] = dados['actual_price_real'].str.replace('.', '').str.replace(',', '.')
# Out:
# <ipython-input-84-2ca5a0846aff>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['actual_price_real'] = dados['actual_price_real'].str.replace('.', '').str.replace(',', '.')

# %%
# Converte coluna para tipo numérico
dados['actual_price_real'] = pd.to_numeric(dados['actual_price_real'])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1465 non-null   object
#  1   product_name       1465 non-null   object
#  2   category           1465 non-null   object
#  3   Subcategory        1465 non-null   object
#  4   actual_price       1465 non-null   float64
#  5   product_price      1465 non-null   float64
#  6   percent_discount   1465 non-null   object
#  7   actual_price_real  1465 non-null   float64
#  8   rating             1465 non-null   object
#  9   rating_count       1465 non-null   int64
#  10  about_product      1465 non-null   object
#  11  product_link       1465 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 137.5+ KB

# %% [markdown]
# ## Graficos

# %%
# Filtra os valores acima de 4.5
ratings_above_4_5 = dados[dados['rating'] >= 4.5]

# Conta a frequência de cada valor
rating_counts = ratings_above_4_5['rating'].value_counts().sort_index()

# Cria o gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=rating_counts.index, y=rating_counts.values)#, color='skyblue')
# plt.bar(rating_counts.index, rating_counts.values, color='skyblue')
plt.xlabel('Avaliação')
plt.ylabel('Contagem')
plt.title('Contagem de Avaliações Acima de 4.5')
plt.show()

# %%
# Filtre os valores até 50 reais
ate_50 = dados[dados['actual_price_real'] <= 50]

# Filtre os valores entre 50 reais e 500 reais
entre_50_500 = dados[(dados['actual_price_real'] > 50) & (dados['actual_price_real'] <= 500)]

# Filtre os valores acima de 500 reais
acima_de_500 = dados[dados['actual_price_real'] > 500]

# Contagem de produtos em cada faixa de valor
contagem = [len(ate_50), len(entre_50_500), len(acima_de_500)]
categorias = ['Até 50 Reais', 'Entre 50 e 500 Reais', 'Acima de 500 Reais']

# Destacar a fatia com o maior valor
explode = (0.1, 0, 0)

# Crie um gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(contagem, labels=categorias, autopct='%1.2f%%', startangle=140, explode=explode)
plt.title('Distribuição de Produtos por Faixa de Valor')
plt.show()
